# %%
import numpy as np

# Load data
headway = np.load('../data/headway_matrix_full.npy')
schedule = np.load('../data/schedule_matrix_full.npy')

# What we have vs what model expects
print("DATA SHAPES:")
print(f"  headway:  {headway.shape}  dtype={headway.dtype}")
print(f"  schedule: {schedule.shape}  dtype={schedule.dtype}")

print("\nMODEL EXPECTS (from model.py):")
print(f"  headway_input:  (batch, 30, 66)  # 30 lookback, 66 stations")
print(f"  schedule_input: (batch, 15, 66)  # 15 forecast, 66 stations")

print("\nQUICK STATS:")
print(f"  headway  - min: {np.nanmin(headway):.2f}, max: {np.nanmax(headway):.2f}, NaN%: {100*np.isnan(headway).mean():.2f}%")
print(f"  schedule - min: {np.nanmin(schedule):.2f}, max: {np.nanmax(schedule):.2f}, NaN%: {100*np.isnan(schedule).mean():.2f}%")
# Out:
# DATA SHAPES:
#   headway:  (264222, 66, 2, 1)  dtype=float64
#   schedule: (264222, 2, 1)  dtype=float64
#
# MODEL EXPECTS (from model.py):
#   headway_input:  (batch, 30, 66)  # 30 lookback, 66 stations
#   schedule_input: (batch, 15, 66)  # 15 forecast, 66 stations
#
# QUICK STATS:
#   headway  - min: 0.00, max: 30.00, NaN%: 0.00%
#   schedule - min: 0.00, max: 63.50, NaN%: 0.00%
