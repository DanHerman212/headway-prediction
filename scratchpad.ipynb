# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import requests
# ----> 2 from google.transit import gtfs_realtime_pb2
#       3 from google.protobuf.json_format import MessageToDict
#       5 url = "https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/camsys%2Fsubway-alerts"
#
# ModuleNotFoundError: No module named 'google.transit'
